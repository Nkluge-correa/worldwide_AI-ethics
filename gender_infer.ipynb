# %% [markdown]
# # Author's Genders
#
# Return to the [index](https://github.com/Nkluge-correa/worldwide_AI-ethics).
#
# **Use this notebook to infer the gender of all authors by using their first name and the [Genderize.io API](https://genderize.io/). Currently (February 25, 2023), no API key is required for less than 1000 requests/day.**

# %%
import pandas as pd

df = pd.read_parquet('data/authors_names')

display(df)
# Out:
#                                                   name        country  \
# 0    An Open Letter to the Global South: Bring the ...         Brazil
# 1    Intel’s AI Privacy Policy White Paper: Protect...  United States
# 2          Everyday Ethics for Artificial Intelligence  United States
# 3            Responsible AI: A Global Policy Framework  United States
# 4            Responsible AI: A Global Policy Framework          India
# ..                                                 ...            ...
# 117  "ARCC": An Ethical Framework for Artificial In...          China
# 118        Unified Ethical Frame for Big Data Analysis  United States
# 119  Human rights in the robot age: Challenges aris...    Netherlands
# 120  Human rights in the robot age: Challenges aris...  United States
# 121  Human rights in the robot age: Challenges aris...         Greece
#
#                                                    url code  \
# 0    https://en.airespucrs.org/c%C3%B3pia-carta-aberta   BR
# 1    https://www.intel.com/content/dam/www/public/u...   US
# 2    https://www.ibm.com/watson/assets/duo/pdf/ever...   US
# 3           https://www.itechlaw.org/ResponsibleAI2021   US
# 4           https://www.itechlaw.org/ResponsibleAI2021   IN
# ..                                                 ...  ...
# 117                         https://www.tisi.org/13747   CN
# 118  https://bigdata.fpf.org/wp-content/uploads/201...   US
# 119  https://www.rathenau.nl/sites/default/files/20...   NL
# 120  https://www.rathenau.nl/sites/default/files/20...   US
# 121  https://www.rathenau.nl/sites/default/files/20...   GR
#
#                                                authors
# 0    Nicholas,Diogo,Lara,Carolina,Guilherme,Camila,...
# 1                                       David,Riccardo
# 2                                 Francesca,Noah,Almas
# 3    Charles,John,Susan,Christian,Michael,Khalid,Ri...
# 4                                        Nikhil,Smriti
# ..                                                 ...
# 117                                               Pony
# 118  Martin,Paula,Jennifer,Lynn,Barbara,Miranda,Art...
# 119                                              Joost
# 120                                              Linda
# 121                                              Rinie
#
# [122 rows x 5 columns]

# %%
import re
import json
from unidecode import unidecode
from urllib.request import urlopen

def clean_names(input_data):
    clean_text = input_data.lower().replace("<br />", " ")
    clean_text = re.sub(r"[-()\"#/@;:<>{}=~|.?]", ' ', clean_text)
    clean_text = re.sub(' +', ' ', clean_text)
    return unidecode(clean_text)

df.authors = df.authors.apply(clean_names)

documents = []
authors_names = []
authors_gender = []
infered_nationality = []

for i, string in enumerate(df.authors):
    names = string.split(',')
    for name in names:

        response = urlopen(f"https://api.genderize.io?name={name}&country_id={df.code[i]}")
        decoded = response.read().decode('utf-8')

        authors_names.append(name)
        authors_gender.append(json.loads(decoded)['gender'])
        documents.append(df.name[i])
        infered_nationality.append(df.code[i])
        
gender_df = pd.DataFrame({'nationality': infered_nationality,
                            'authors' : authors_names,
                            'gender': authors_gender,
                            'document' : documents})

gender_df.to_parquet('authors_gender_df', compression='gzip')

display(gender_df)

print(f'Unique names found: {len(gender_df.authors.unique())}')
print(f'Unique nationalies infered: {len(gender_df.nationality.unique())}')
# Out:
#     nationality    authors  gender  \
# 0            BR   nicholas    male
# 1            BR      diogo    male
# 2            BR       lara  female
# 3            BR   carolina  female
# 4            BR  guilherme    male
# ..          ...        ...     ...
# 825          US      susan  female
# 826          US       nick    male
# 827          NL      joost    male
# 828          US      linda  female
# 829          GR      rinie    male
#
#                                               document
# 0    An Open Letter to the Global South: Bring the ...
# 1    An Open Letter to the Global South: Bring the ...
# 2    An Open Letter to the Global South: Bring the ...
# 3    An Open Letter to the Global South: Bring the ...
# 4    An Open Letter to the Global South: Bring the ...
# ..                                                 ...
# 825        Unified Ethical Frame for Big Data Analysis
# 826        Unified Ethical Frame for Big Data Analysis
# 827  Human rights in the robot age: Challenges aris...
# 828  Human rights in the robot age: Challenges aris...
# 829  Human rights in the robot age: Challenges aris...
#
# [830 rows x 4 columns]
# Unique names found: 558
# Unique nationalies infered: 36

# %%
import pandas as pd

gender_df = pd.read_parquet('data/authors_gender_df')

documents = []
male_authors = []
female_authors = []

for document in gender_df.document.unique():

    temp_df = gender_df[gender_df['document'] == document]

    if 'male' in list(temp_df.gender):
        male_authors.append(temp_df.gender.value_counts()['male'])
    else:
        male_authors.append(0)

    if 'female' in list(temp_df.gender):
        female_authors.append(temp_df.gender.value_counts()['female'])
    else:
        female_authors.append(0)

    documents.append(document)


final_gender_df = pd.DataFrame({'document': documents,
                            'male_authors' : male_authors,
                            'female_authors': female_authors})

final_gender_df.to_parquet('data/final_gender_df',  compression='gzip')
display(final_gender_df)

print(f'Male Authors: {final_gender_df.male_authors.sum()}')
print(f'Female Authors {final_gender_df.female_authors.sum()}')
# Out:
#                                              document  male_authors  \
# 0   An Open Letter to the Global South: Bring the ...            13
# 1   Intel’s AI Privacy Policy White Paper: Protect...             2
# 2         Everyday Ethics for Artificial Intelligence             1
# 3           Responsible AI: A Global Policy Framework            32
# 4                                 KI Seal of Approval             9
# ..                                                ...           ...
# 63          Trustworthy AI in Aotearoa: AI Principles             1
# 64      Harmonious Artificial Intelligence Principles             1
# 65  "ARCC": An Ethical Framework for Artificial In...             2
# 66        Unified Ethical Frame for Big Data Analysis             4
# 67  Human rights in the robot age: Challenges aris...             2
#
#     female_authors
# 0                5
# 1                0
# 2                2
# 3               18
# 4                1
# ..             ...
# 63               1
# 64               0
# 65               0
# 66               7
# 67               1
#
# [68 rows x 3 columns]
# Male Authors: 549
# Female Authors 281

# %% [markdown]
# ---
#
# Return to the [index](https://github.com/Nkluge-correa/worldwide_AI-ethics).
