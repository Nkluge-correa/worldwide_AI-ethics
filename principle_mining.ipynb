# %% [markdown]
# # Principle Mining ⚖️
#
# Return to the [index](https://github.com/Nkluge-correa/worldwide_AI-ethics).
#
# Use the cell below to extract the principles from the raw dataset.

# %%
import pandas as pd

df = pd.read_parquet("data/data_raw.parquet")

accountability = []
beneficence = []
children = []
dignity = []
diversity = []
freedom = []
education = []
alignment = []
intellectual = []
justice = []
labor = []
openess = []
privacy = []
reliability = []
sustainability = []
transparency = []
truth = []

names = [f'[{df.document_name[i]}]({df.document_url[i]})' for i in range(len(df))]

for i in range(len(df)):

    principles_text = df.principles_definition[i]
    principles = principles_text.split('#')
    for principle in principles:

        if "Accountability/Liability:" in principle:
            principle = principle.replace("Accountability/Liability:", "")
            accountability.append(f'{names[i]}: {principle.rstrip().lstrip()}')
        
        if "Beneficence/Non-Maleficence:" in principle:
            principle = principle.replace("Beneficence/Non-Maleficence:", "")
            beneficence.append(f'{names[i]}: {principle.rstrip().lstrip()}')
        
        if "Children & Adolescents Rights:" in principle:
            principle = principle.replace("Children & Adolescents Rights:", "")
            children.append(f'{names[i]}: {principle.rstrip().lstrip()}')
        
        if "Dignity/Human Rights:" in principle:
            principle = principle.replace("Dignity/Human Rights:", "")
            dignity.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Diversity/Inclusion/Pluralism/Accessibility:" in principle:
            principle = principle.replace(
                "Diversity/Inclusion/Pluralism/Accessibility:", "")
            diversity.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Freedom/Autonomy/Democratic Values/Technological Sovereignty:" in principle:
            principle = principle.replace(
                "Freedom/Autonomy/Democratic Values/Technological Sovereignty:", "")
            freedom.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Human Formation/Education:" in principle:
            principle = principle.replace("Human Formation/Education:", "")
            education.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Human-Centeredness/Alignment:" in principle:
            principle = principle.replace("Human-Centeredness/Alignment:", "")
            alignment.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Intellectual Property:" in principle:
            principle = principle.replace("Intellectual Property:", "")
            intellectual.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Justice/Equity/Fairness/Non-discrimination:" in principle:
            principle = principle.replace(
                "Justice/Equity/Fairness/Non-discrimination:", "")
            justice.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Labor Rights:" in principle:
            principle = principle.replace("Labor Rights:", "")
            labor.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Open source/Fair Competition/Cooperation:" in principle:
            principle = principle.replace("Open source/Fair Competition/Cooperation:", "")
            openess.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Privacy:" in principle:
            principle = principle.replace("Privacy:", "")
            privacy.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Reliability/Safety/Security/Trustworthiness:" in principle:
            principle = principle.replace("Reliability/Safety/Security/Trustworthiness:", "")
            reliability.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Sustainability:" in principle:
            principle = principle.replace("Sustainability:", "")
            sustainability.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Transparency/Explainability/Auditability:" in principle:
            principle = principle.replace("Transparency/Explainability/Auditability:", "")
            transparency.append(f'{names[i]}: {principle.rstrip().lstrip()}')

        if "Truthfulness:" in principle:
            principle = principle.replace("Truthfulness:", "")
            truth.append(f'{names[i]}: {principle.rstrip().lstrip()}')

data = {
    'accountability': accountability,
    'beneficence': beneficence,
    "children_rights": children,
    'dignity': dignity,
    'diversity': diversity,
    'autonomy': freedom,
    'human_formation': education,
    'human_centeredness': alignment,
    'intellectual_property': intellectual,
    'fairness': justice,
    'labor_rights': labor,
    'cooperation': openess,
    'privacy': privacy,
    'reliability': reliability,
    'sustainability': sustainability,
    'transparency': transparency,
    'truthfulness': truth

}

new_df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in data.items()]))
display(new_df)
#new_df.to_parquet('principle_definition', compression='gzip')
# Out:
#                                         accountability  \
# 0    [Declaration on Ethics and Data Protection in ...
# 1    [Intel’s AI Privacy Policy White Paper: Protec...
# 2    [AI Policies and Principles ](https://www.itic...
# 3    [Artificial Intelligence and Machine Learning:...
# 4    [Everyday Ethics for Artificial Intelligence](...
# ..                                                 ...
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
#
#                                            beneficence  \
# 0    [Intel’s AI Privacy Policy White Paper: Protec...
# 1    [Icelander Institute for Intelligent Machine E...
# 2    [Responsible AI: A Global Policy Framework](ht...
# 3    [The Japanese Society for Artificial Intellige...
# ...

# %% [markdown]
# Use the cell below to extract the principles for text mining. We are using a custom `stopword.txt` file to filter common words (like "_the_" or "_and_") found in our sample (like "_ai_" and "_intelligence_").

# %%
import pandas as pd
import plotly.express as px
import plotly.offline as py
from sklearn.feature_extraction.text import CountVectorizer

df = pd.read_parquet('data/data_raw.parquet')

accountability = []
beneficence = []
children = []
dignity = []
diversity = []
freedom = []
education = []
alignment = []
intellectual = []
justice = []
labor = []
openess = []
privacy = []
reliability = []
sustainability = []
transparency = []
truth = []

for i in range(len(df)):

    principles_text = df.principles_definition[i]
    principles = principles_text.split('#')
    for principle in principles:

        if "Accountability/Liability:" in principle:
            principle = principle.replace("Accountability/Liability:", "")
            accountability.append(principle.rstrip().lstrip())
        
        if "Beneficence/Non-Maleficence:" in principle:
            principle = principle.replace("Beneficence/Non-Maleficence:", "")
            beneficence.append(principle.rstrip().lstrip())
        
        if "Children & Adolescents Rights:" in principle:
            principle = principle.replace("Children & Adolescents Rights:", "")
            children.append(principle.rstrip().lstrip())
        
        if "Dignity/Human Rights:" in principle:
            principle = principle.replace("Dignity/Human Rights:", "")
            dignity.append(principle.rstrip().lstrip())

        if "Diversity/Inclusion/Pluralism/Accessibility:" in principle:
            principle = principle.replace(
                "Diversity/Inclusion/Pluralism/Accessibility:", "")
            diversity.append(principle.rstrip().lstrip())

        if "Freedom/Autonomy/Democratic Values/Technological Sovereignty:" in principle:
            principle = principle.replace(
                "Freedom/Autonomy/Democratic Values/Technological Sovereignty:", "")
            freedom.append(principle.rstrip().lstrip())

        if "Human Formation/Education:" in principle:
            principle = principle.replace("Human Formation/Education:", "")
            education.append(principle.rstrip().lstrip())

        if "Human-Centeredness/Alignment:" in principle:
            principle = principle.replace("Human-Centeredness/Alignment:", "")
            alignment.append(principle.rstrip().lstrip())

        if "Intellectual Property:" in principle:
            principle = principle.replace("Intellectual Property:", "")
            intellectual.append(principle.rstrip().lstrip())

        if "Justice/Equity/Fairness/Non-discrimination:" in principle:
            principle = principle.replace(
                "Justice/Equity/Fairness/Non-discrimination:", "")
            justice.append(principle.rstrip().lstrip())

        if "Labor Rights:" in principle:
            principle = principle.replace("Labor Rights:", "")
            labor.append(principle.rstrip().lstrip())

        if "Open source/Fair Competition/Cooperation:" in principle:
            principle = principle.replace("Open source/Fair Competition/Cooperation:", "")
            openess.append(principle.rstrip().lstrip())

        if "Privacy:" in principle:
            principle = principle.replace("Privacy:", "")
            privacy.append(principle.rstrip().lstrip())

        if "Reliability/Safety/Security/Trustworthiness:" in principle:
            principle = principle.replace("Reliability/Safety/Security/Trustworthiness:", "")
            reliability.append(principle.rstrip().lstrip())

        if "Sustainability:" in principle:
            principle = principle.replace("Sustainability:", "")
            sustainability.append(principle.rstrip().lstrip())

        if "Transparency/Explainability/Auditability:" in principle:
            principle = principle.replace("Transparency/Explainability/Auditability:", "")
            transparency.append(principle.rstrip().lstrip())

        if "Truthfulness:" in principle:
            principle = principle.replace("Truthfulness:", "")
            truth.append(principle.rstrip().lstrip())

data = {
    'accountability': accountability,
    'beneficence': beneficence,
    "children_rights": children,
    'dignity': dignity,
    'diversity': diversity,
    'autonomy': freedom,
    'human_formation': education,
    'human_centeredness': alignment,
    'intellectual_property': intellectual,
    'fairness': justice,
    'labor_rights': labor,
    'cooperation': openess,
    'privacy': privacy,
    'reliability': reliability,
    'sustainability': sustainability,
    'transparency': transparency,
    'truthfulness': truth

}

text_mining_df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in data.items()]))

principles = [list(text_mining_df[column].dropna()) for column in text_mining_df.columns]

def get_top_n_words(corpus, top_k, n ):
    vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:top_k]

for i in range(len(principles)):

    common_words = get_top_n_words(principles[i], 20, 4)

    word, freq = zip(*common_words)

    fig = px.bar(x=word, y=freq,
                 title=f'Top-20 Words (fourgrams) in principle: {text_mining_df.columns[i]}.',
                 color=freq, color_continuous_scale='reds')
    
    fig.update_layout(template='plotly_dark',
                    paper_bgcolor='rgba(0, 0, 0, 0)',
                    plot_bgcolor='rgba(0, 0, 0, 0)')
    
    fig.show()

    temp_df = pd.DataFrame({'Top four-grams': word,
                            'Word Count': freq})
    temp_df.to_parquet(f'data/n-grams/{text_mining_df.columns[i]}_gram.parquet', compression='gzip')

# %% [markdown]
# ---
#
# Return to the [index](https://github.com/Nkluge-correa/worldwide_AI-ethics).
